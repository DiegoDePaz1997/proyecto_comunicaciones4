# %%
from math import pi
import numpy as np
R = 10_000 
c = 100*10**-9
w = 60*(2*pi)
Xc = complex(0, -1/(w*c))

print(Xc)
# Out:
# -26525.823848649223j

# %%
div = 120*Xc/(Xc + R)
angulo = np.arctan2(div.imag, div.real)
print(f'angulo = {np.rad2deg(angulo)}')
print(div)
print(abs(div))
# Out:
# angulo = -20.655997382339656
# (105.06755681534705-39.609535754606696j)
# 112.2858264334446

# %%
angulo = np.arctan2(ima.imag, ima.real)
print(np.rad2deg(angulo))
# Out:
# 37.15778527494531
